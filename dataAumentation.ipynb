# %% [markdown]
# ImageDataGenerator
#
# reference: https://juejin.im/post/6844904024915853319

# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt

img_generator =  ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    channel_shift_range=0.1,
    brightness_range=(0.6, 1),
)

img_path = '/Users/liuliangjun/Downloads/test6.png'
img = image.load_img(img_path)
plt.imshow(img)

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
gen = img_generator.flow(x, batch_size=1)

plt.figure(figsize=(12,10))
for i in range(3):
    for j in range(3):
        x_batch = next(gen)
        idx = (3*i) + j
        plt.subplot(3, 3, idx+1)
        plt.imshow(x_batch[0]/256)
plt.show()

# %%
help(img_generator.flow_from_directory)

"""
interpolation:
nearest - 最邻近插值 (default)
bilinear - 双线性插值，如果最后一个参数你不指定，默认使用这种方法
bicubic - 4x4像素邻域内的双立方插值
lanczos - 8x8像素邻域内的Lanczos插值
"""
# Out:
# Help on method flow_from_directory in module keras.preprocessing.image:
#
# flow_from_directory(directory, target_size=(256, 256), color_mode='rgb', classes=None, class_mode='categorical', batch_size=32, shuffle=True, seed=None, save_to_dir=None, save_prefix='', save_format='png', follow_links=False, subset=None, interpolation='nearest') method of keras.preprocessing.image.ImageDataGenerator instance
#     Takes the path to a directory & generates batches of augmented data.
#
#     # Arguments
#         directory: string, path to the target directory.
#             It should contain one subdirectory per class.
#             Any PNG, JPG, BMP, PPM or TIF images
#             inside each of the subdirectories directory tree
#             will be included in the generator.
#             See [this script](
#             https://gist.github.com/fchollet/0830affa1f7f19fd47b06d4cf89ed44d)
#             for more details.
#         target_size: Tuple of integers `(height, width)`,
# ...

# %%
from PIL import Image
# from ipykernel import display

test_img = Image.open('/Users/liuliangjun/Downloads/test17.jpg')
test_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x337 at 0x135B9C438>

# %%
test_img.resize((300, 300), resample=Image.BOX)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x135D29208>

# %%
test_img.resize((300, 300), resample=Image.NEAREST)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x13D59BCC0>

# %%
test_img.resize((300, 300), resample=Image.BILINEAR)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x134CCF7B8>

# %%
test_img.resize((300, 300), resample=Image.BICUBIC)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x135B9C4E0>

# %%
test_img.resize((300, 300), resample=Image.LANCZOS)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x13D61A0B8>

# %%
test_img.resize((300, 300), resample=Image.HAMMING)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x135D29A20>
